# %%
# load libraries 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# sample data
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0, 75, 50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np. array([110, 180, 240, 99, 220])

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2,
                               nrows = 1,
                               figsize = (7,3))

ax1.scatter(x1,y1)
ax2.bar(x2,y2)
# Out:
# <BarContainer object of 5 artists>

# %%
# adding modification to plots
fig, (ax1, ax2) = plt.subplots(ncols = 2,
                               nrows = 1,
                               figsize = (7,3))

ax1.scatter(x1,y1, color = "red") # change colour
ax2.bar(x2,y2, color = "blue") # change colour
ax2.set_xlabel("Names", fontsize = 14) # add x-axis label to barplot

# add titles to plots
ax1.set_title("Scatter Plot", fontsize = 18)
ax2.set_title("Bar Plot", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Bar Plot')

# %%
# subplots without a grid arrangement
# we can first create a mosaic, then add data to each subplot the same way we did before

fig, someaxes = plt.subplot_mosaic([["ax1", "ax3"],
                                    ["ax2", "ax3"]],
                                    figsize = (7, 4))

someaxes["ax1"].scatter(x1,y1) 
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

# %%
# adding some large x-axis titles 
fig, someaxes = plt.subplot_mosaic([["ax1", "ax3"],
                                    ["ax2", "ax3"]],
                                    figsize = (7, 4))

someaxes["ax1"].scatter(x1,y1) 
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes["ax1"].set_xlabel("A Big Label", fontsize = 18)
someaxes["ax2"].set_xlabel("Another Label", fontsize = 18)
someaxes["ax3"].set_xlabel("Label 2: 2 Fast 2 Furious", fontsize = 18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %% [markdown]
# ax1 x-axis plot did not show, and Label 2 x-axis is cut off. To resolve this, we can create constrained layouts

# %%
fig, someaxes = plt.subplot_mosaic([["ax1", "ax3"],
                                    ["ax2", "ax3"]],
                                    figsize = (7, 4),
                                    layout = "constrained") # add layout argument to make subplots constrained

someaxes["ax1"].scatter(x1,y1) 
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes["ax1"].set_xlabel("A Big Label", fontsize = 18)
someaxes["ax2"].set_xlabel("Another Label", fontsize = 18)
someaxes["ax3"].set_xlabel("Label 2: 2 Fast 2 Furious", fontsize = 18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %% [markdown]
# The plots shrunk to fit the x-axis labels.

# %%
# multiple plots on one axes object

# first make our sample data
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])

# define our figure and axes (just one this time)
fig, ax = plt.subplots(figsize=(7,3))

# now call both bar and plot elements to the same axes (ax)
ax.bar(x, y1,
       color = "indigo")
ax.plot(x,y2,
        color="red")
# this results in a purple bar chart with red line on the same axes

# %%
# add error information
# first, calculate SD of data
y2_sd = np.std(y2)

# plot line plot as before
fig, ax = plt.subplots(figsize= (7,3))
ax.plot(x, y2, color = "red")

# use errorbar() to add error line
ax.errorbar(x, # our x values
            y2, # our y values
            yerr = y2_sd, # sd values
            fmt = "none") # don't want data points, just want bar
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# can customize errorbar appearance
fig, ax = plt.subplots(figsize= (7,3))
ax.plot(x, y2, color = "red")

ax.errorbar(x,
            y2, 
            yerr = y2_sd, 
            fmt = "none",
            ecolor = "indigo",
            elinewidth = 4,
            capsize = 6,
            capthick = 4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# errorevery

fig, ax = plt.subplots(figsize= (7,3))
ax.plot(x, y2, color = "red")

ax.errorbar(x,
            y2, 
            yerr = y2_sd, 
            fmt = "none",
            ecolor = "indigo",
            elinewidth = 4,
            capsize = 6,
            capthick = 4,
            errorevery=2) # every two points has an error bar
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# add images to plots

# load libraries
from PIL import Image # to open images
import requests # to get images from URLs
from io import BytesIO # to store images

# %%
# get image from the internet

response = requests.get("https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png")
image_file = BytesIO(response.content)
image = Image.open(image_file)

# %%
# can make our basic line plot again
fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2, color="red")

# %%
# going to overlay a new axis on the figure above, to act as a container for the image

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2, color="red")

ax_image = fig.add_axes([0.1, # x coordinate (on figure, not axis)
                         0.11, # y coordinate (on figure, not axis)
                         0.15, #image width
                         0.35 # image height
                         ])

# %% [markdown]
# Can see we added an empty axes object on top. This way, we can see where it goes before adding our image

# %%
fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2, color="red")

ax_image = fig.add_axes([0.1, # x coordinate (on figure, not axis)
                         0.11, # y coordinate (on figure, not axis)
                         0.15, #image width
                         0.35 # image height
                         ])

# adding the image
ax_image.imshow(image) # add image
ax_image.axis("off") # this will get rid of the border around the axes object
# Out:
# (-0.5, 219.5, 425.5, -0.5)

# %%
# can save visualizations programmatically 
# path = "C:/Users/..."
# filename = "/fig1a.png" # note that path shouldn't end with / since the filename starts with it

# plt.savefig(path+filename, dpi=300)
